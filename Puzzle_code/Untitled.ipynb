# %%
from PuzzleGenerator import PuzzleGenerator
from PIL import Image

# %%
N = 4
pg = PuzzleGenerator("images/IMG_6554.jpg", N, N-1)

# %%
pg.generate()

# %%
display(Image.fromarray(pg.pieces_arr[0][2]))
display(Image.fromarray(pg.pieces_arr[0][1]))
display(Image.fromarray(pg.pieces_arr[1][2]))
# Out:
# <PIL.Image.Image image mode=RGBA size=618x618>
# <PIL.Image.Image image mode=RGBA size=618x618>
# <PIL.Image.Image image mode=RGBA size=618x618>
