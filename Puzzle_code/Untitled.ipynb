# %%
from PuzzleGenerator import PuzzleGenerator
from PIL import Image

# %%
N = 4
pg = PuzzleGenerator("images/IMG_6554.jpg", N, N)

# %%
pg.generate()

# %%
display(Image.fromarray(pg.pieces_arr[0][0]))
# Out:
# <PIL.Image.Image image mode=RGBA size=618x618>
